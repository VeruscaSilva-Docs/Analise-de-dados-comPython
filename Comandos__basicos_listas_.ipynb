# %% [markdown]
# <a href="https://colab.research.google.com/github/VeruscaSilva-Docs/Analise-de-dados-comPython/blob/main/Comandos__basicos_listas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TESTANDO COMANDOS

# %%
nome = 'VERUSCA'
nome2 = "TAIANE"

# %%
nome
# Out:
# 'VERUSCA'

# %%
nome2
# Out:
# 'TAIANE'

# %% [markdown]
# TIPOS DE DADOS
#
# https://docs.python.org/pt-br/3/library/datatypes.html
#
# Documentação Python  tipos de dados

# %%
qtd=5
type(qtd)
# Out:
# int

# %%
pc_produto=100.50
type(pc_produto)
# Out:
# float

# %%
nome = "verusca silva"
type(nome)
# Out:
# str

# %%
tem_acesso = False
type(tem_acesso)
# Out:
# bool

# %%
itens=20
valor=70.35
total_compra = itens*valor
total_compra
# Out:
# 1407.0

# %%
type(total_compra)
# Out:
# float

# %% [markdown]
# **Tipos de Comentários**

# %%
"""Comentar texto
mais de uma
linha , inserir varios comentarios ou comentario grande"""
m=12
print(m)
# Out:
# 12

# %%
m=13
print(m)
# Out:
# 13

# %%
from google.colab import drive
drive.mount('/content/drive')
